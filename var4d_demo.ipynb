# %%
# %pip install rdata
# Out:
# Collecting rdata
#   Using cached rdata-0.11.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rdata) (1.26.4)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rdata) (2024.3.0)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rdata) (2.2.1)
# Requirement already satisfied: typing-extensions>4.4 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rdata) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas->rdata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas->rdata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas->rdata) (2024.1)
# Requirement already satisfied: packaging>=22 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from xarray->rdata) (24.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->rdata) (1.16.0)
# Using cached rdata-0.11.2-py3-none-any.whl (46 kB)
# Installing collected packages: rdata
# Successfully installed rdata-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from var4d_components import Var4D_Components
from visualize_results import Visualize_Obs, Visualize_Fluxes
import os
os.environ['OMP_NUM_THREADS'] = '8' # use multi-threaded library

# %%
var4d = Var4D_Components('first_try', verbose=True, store_intermediate=True)
obs_to_assim = {'sites': ['mlo', 'spo']}
var4d.var4d_chain(max_iter=500, optim_method='BFGS', obs_to_assim=obs_to_assim)
# Out:
# Converting CT2022 to state vector: 100%|██████████| 24/24 [00:01<00:00, 20.92it/s]
#     Read Jacobian in  18.47s
#     Simulated transport in  0.50s
#   Created true obs in  20.75s
# Converting SiB4 to state vector: 100%|██████████| 24/24 [00:02<00:00,  8.13it/s]
#   Prior fluxes and covariance setup in  3.10s
#   Simulated transport in  0.49s
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 1.012e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7662)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 7948)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 5258)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 5462)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3887)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 2207)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3731)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.206e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4299)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 1549)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3704)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 2552)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3750)
#       Simulated transport in  0.50s
#     Cost calculated in  0.59s (J = 1359)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3672)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 1162)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 3606)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 1098)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 3461)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 1022)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3360)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 919.8)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 3180)
#       Simulated transport in  0.51s
#     Cost calculated in  0.61s (J = 744)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2847)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 549.8)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2065)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 325.2)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1124)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 523)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 180.2)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 246.2)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 686)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 289.1)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 191)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 214.8)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 485.9)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 184.4)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 257.9)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 164.6)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 30.74)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 165.2)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 98.58)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 154.8)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 35.87)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 162.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 37.56)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 151.2)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 34.85)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 153.3)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 21.34)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 149.8)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 28.37)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 150.2)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 5.011)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 149.2)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 16.67)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 149.7)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 6.987)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 149)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 8.706)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 149.2)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4.792)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 4.527)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.396)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.518)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.7724)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.8204)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.1164)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.365)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 0.1081)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.04965)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.05099)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.04947)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.00898)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.01242)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.001499)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.002483)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001237)
#       Simulated transport in  0.51s
#     Cost calculated in  0.64s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0003683)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0006045)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0002032)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 7.85e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 5.547e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 148.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8.791e-06)
# Optimization terminated successfully.
#          Current function value: 148.850829
#          Iterations: 36
#          Function evaluations: 54
#          Gradient evaluations: 54
#   Optimization finished in  1m 7.11s
#   Simulated transport in  0.52s

# %%
po = Visualize_Obs('first_try')

# %%
po.plot_site(['spo','mlo','amt'])

# %%
po.plot_site(['brw','smo','lef'])

# %%
obs_to_assim = {'sites': ['mlo','brw','smo','spo']}
var4d.var4d_chain(max_iter=500, optim_method='BFGS', obs_to_assim=obs_to_assim)
# Out:
# Converting CT2022 to state vector: 100%|██████████| 24/24 [00:00<00:00, 34.95it/s]
#     Simulated transport in  0.50s
#   Created true obs in  2.04s
# Converting SiB4 to state vector: 100%|██████████| 24/24 [00:02<00:00, 11.34it/s]
#   Prior fluxes and covariance setup in  2.27s
#   Simulated transport in  0.49s
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 3.015e+04)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 8231)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 2.521e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7480)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 1.69e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 4769)
#       Simulated transport in  0.50s
#     Cost calculated in  0.60s (J = 1.564e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 8215)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 1.364e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7869)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.641e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8251)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.303e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 7870)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.243e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7804)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.189e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 7698)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 1.129e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 7539)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.1e+04)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 7345)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 1.059e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 7197)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 9928)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 6977)
#       Simulated transport in  0.49s
#     Cost calculated in  0.60s (J = 8763)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 6549)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 6973)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 5747)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 5605)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4483)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 5003)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3458)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 4212)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 2961)
#       Simulated transport in  0.49s
#     Cost calculated in  0.64s (J = 3543)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2320)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 2907)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1757)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 2511)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1246)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 2080)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 903.3)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 1698)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 595.9)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 1701)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 440.7)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 1506)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 471.9)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 1220)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 359.2)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 906.8)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 242.8)
#       Simulated transport in  0.51s
#     Cost calculated in  0.64s (J = 664)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 148.8)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 697.8)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 145.3)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 549.3)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 108.6)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 569.1)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 132.6)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 495.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 91.99)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 460.2)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 70.62)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 451.7)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 60.09)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 439.3)
#     Gradient calculated in  0.66s (⎸∂J/∂ξ⎹ = 49.35)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 427.6)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 45.12)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 417.4)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 37.26)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 407.1)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 27.01)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 404.5)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 28.44)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 400.8)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 22.19)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 399.5)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 21.87)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 397.5)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 18.04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 395.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 14.4)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 395)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 10.71)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 394.1)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 6.491)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 393.4)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 4.164)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 393.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 6.387)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 393.2)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3.268)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393.3)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4.539)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393.1)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.772)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.071)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.578)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.442)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 393)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.298)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.9867)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.5126)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.365)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.3409)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.2232)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.2079)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.1278)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.1182)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0507)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.1477)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.02525)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.06253)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0146)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.03718)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.01005)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.005919)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.004546)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.004155)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 0.002816)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001959)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.00151)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0006512)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001317)
#       Simulated transport in  0.51s
#     Cost calculated in  0.64s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.000428)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0008363)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0002216)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0003777)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8.231e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0001283)
#       Simulated transport in  0.49s
#     Cost calculated in  0.61s (J = 392.9)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.635e-05)
# Optimization terminated successfully.
#          Current function value: 392.914452
#          Iterations: 66
#          Function evaluations: 84
#          Gradient evaluations: 84
#   Optimization finished in  1m 44.77s
#   Simulated transport in  0.51s

# %%
po.plot_site(['spo','mlo','amt'])

# %%
po.plot_site(['kum','brw','lef'])

# %%
obs_to_assim = {'oco2': True}
var4d.var4d_chain(max_iter=500, optim_method='BFGS', obs_to_assim=obs_to_assim)
# Out:
# Converting CT2022 to state vector: 100%|██████████| 24/24 [00:00<00:00, 33.80it/s]
#     Simulated transport in  0.49s
#   Created true obs in  1.36s
# Converting SiB4 to state vector: 100%|██████████| 24/24 [00:02<00:00, 11.94it/s]
#   Prior fluxes and covariance setup in  2.16s
#   Simulated transport in  0.49s
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 4.55e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.079e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 4.208e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.201e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 3.614e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 1.997e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.59s (J = 2.662e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.999e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 2.106e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.057e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.57s (J = 5.132e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.307e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 2.03e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.054e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.913e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.052e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.841e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.053e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.821e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.053e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.792e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.053e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.762e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.052e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.758e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.052e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.751e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.052e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.74e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.052e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.734e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.051e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.726e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.051e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.714e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.05e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.705e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.048e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.698e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.047e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.69e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.045e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.684e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.043e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.676e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.042e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.67e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.038e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.662e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.036e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.654e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.032e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.646e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.027e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.638e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.022e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.626e+06)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 2.016e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.615e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.007e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.55s (J = 1.601e+06)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.997e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.586e+06)
#     Gradient calculated in  0.67s (⎸∂J/∂ξ⎹ = 1.985e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.56s (J = 1.565e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.97e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.534e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.95e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.56s (J = 1.503e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.918e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.47e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.885e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.56s (J = 1.428e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.849e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.56s (J = 1.385e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.802e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.57s (J = 1.365e+06)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1.752e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.57s (J = 1.331e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.729e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.57s (J = 1.278e+06)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1.689e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.57s (J = 1.213e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.624e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.57s (J = 1.149e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.546e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.57s (J = 1.07e+06)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.466e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.57s (J = 9.862e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.367e+06)
#       Simulated transport in  0.49s
#     Cost calculated in  0.57s (J = 9.065e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.259e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.58s (J = 8.062e+05)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 1.157e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.58s (J = 7.141e+05)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 1.026e+06)
#       Simulated transport in  0.50s
#     Cost calculated in  0.59s (J = 6.238e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 9.043e+05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.58s (J = 5.449e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7.842e+05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.58s (J = 4.592e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 6.781e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.60s (J = 3.988e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 5.62e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.59s (J = 3.363e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4.794e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.60s (J = 2.87e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 3.935e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.60s (J = 2.514e+05)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3.251e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.61s (J = 2.328e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.754e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.61s (J = 2.117e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.492e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.61s (J = 1.88e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.193e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.794e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.857e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.69e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.733e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.592e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.584e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.61s (J = 1.503e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.442e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.419e+05)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.313e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.323e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.192e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.223e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.053e+05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.174e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 9.094e+04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 1.116e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8.391e+04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 1.061e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7.582e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 1.013e+05)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 6.82e+04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 9.641e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 6.157e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.62s (J = 9.145e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 5.514e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8.847e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 4.877e+04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8.484e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4.503e+04)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8.092e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 4.07e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 7.718e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 3.618e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 7.293e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3.206e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 6.9e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.767e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 6.417e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 2.385e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 5.879e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.956e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 5.521e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.541e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 5.127e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.289e+04)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 4.823e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1.089e+04)
#       Simulated transport in  0.52s
#     Cost calculated in  0.66s (J = 4.446e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 9725)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 4.152e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 9113)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 3.837e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 8899)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 3.603e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 9084)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 3.368e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 9222)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 3.106e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 9346)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 2.815e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 9419)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 2.6e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 9430)
#       Simulated transport in  0.50s
#     Cost calculated in  0.65s (J = 2.369e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 9254)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 2.154e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 9005)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.97e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 8628)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.811e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 8174)
#       Simulated transport in  0.50s
#     Cost calculated in  0.65s (J = 1.678e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 7656)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.531e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 7102)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.489e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 6461)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.425e+04)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 6191)
#       Simulated transport in  0.50s
#     Cost calculated in  0.65s (J = 1.35e+04)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 5775)
#       Simulated transport in  0.51s
#     Cost calculated in  0.65s (J = 1.281e+04)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 5222)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.246e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 4664)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.211e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 4318)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.173e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3949)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.133e+04)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 3513)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.108e+04)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 3040)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.084e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 2705)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.057e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 2369)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.04e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 2016)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.023e+04)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1768)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.016e+04)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 1558)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 1.003e+04)
#     Gradient calculated in  0.66s (⎸∂J/∂ξ⎹ = 1443)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9890)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1293)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9850)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1163)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9787)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 1106)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9717)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 1046)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9640)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 973.7)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9556)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 897.4)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9467)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 811.1)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 9390)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 727.5)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9317)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 649.8)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 9234)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 573.4)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 9148)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 489.3)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9104)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 424.3)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 9059)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 367.9)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 9017)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 323.8)
#       Simulated transport in  0.51s
#     Cost calculated in  0.65s (J = 8993)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 290.6)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8965)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 252.8)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8958)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 245.6)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8947)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 228.9)
#       Simulated transport in  0.51s
#     Cost calculated in  0.64s (J = 8935)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 218.2)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8924)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 202.6)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8914)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 184.6)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8910)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 174.3)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8905)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 164)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8900)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 155.5)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8895)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 144.9)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8892)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 134)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8888)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 123.2)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8883)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 112.7)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8880)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 100.6)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8876)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 89.25)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8873)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 78.97)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8871)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 69.85)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8869)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 62.99)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8868)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 55.38)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8866)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 47.85)
#       Simulated transport in  0.51s
#     Cost calculated in  0.65s (J = 8865)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 41.41)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8864)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 35.07)
#       Simulated transport in  0.52s
#     Cost calculated in  0.66s (J = 8863)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 30.52)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8863)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 26.43)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8862)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 22.91)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8862)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 23.05)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8862)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 20.95)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8862)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 18.65)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8862)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 17.53)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 15.65)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 14.55)
#       Simulated transport in  0.52s
#     Cost calculated in  0.66s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 13.55)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 12.22)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 11.34)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 10.93)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 10.26)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 9.818)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8.996)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 8.021)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 7.043)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 5.897)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 5.356)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 4.894)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 4.561)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3.902)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3.593)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 3.221)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 2.984)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.64s (⎸∂J/∂ξ⎹ = 2.638)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.372)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 2.061)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.848)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 1.564)
#       Simulated transport in  0.52s
#     Cost calculated in  0.65s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.468)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.25)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 1.106)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.9154)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.7549)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.6065)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.5114)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.4161)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.4218)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.3698)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.3524)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 0.2982)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 0.2768)
#       Simulated transport in  0.48s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.2359)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.219)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.1891)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.1701)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.1462)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.124)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.60s (⎸∂J/∂ξ⎹ = 0.1044)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0871)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.07245)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.06457)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0534)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.04552)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.03967)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.03541)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.03122)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.02776)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.02335)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.01986)
#       Simulated transport in  0.50s
#     Cost calculated in  0.64s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.01585)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.01435)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.01209)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.01099)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.008769)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.007219)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.006056)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.00492)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.004397)
#       Simulated transport in  0.49s
#     Cost calculated in  0.62s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.003832)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.003146)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.003053)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.002716)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.002484)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.002003)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001583)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001268)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.001033)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.66s (⎸∂J/∂ξ⎹ = 0.0008488)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0007351)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0005763)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0004597)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 0.0004336)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0003639)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0002965)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.61s (⎸∂J/∂ξ⎹ = 0.0002029)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0002381)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0001675)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 0.0001369)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 0.0001032)
#       Simulated transport in  0.50s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 8.979e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 7.673e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.62s (⎸∂J/∂ξ⎹ = 6.428e-05)
#       Simulated transport in  0.49s
#     Cost calculated in  0.63s (J = 8861)
#     Gradient calculated in  0.63s (⎸∂J/∂ξ⎹ = 5.465e-05)
# Optimization terminated successfully.
#          Current function value: 8860.594319
#          Iterations: 238
#          Function evaluations: 244
#          Gradient evaluations: 244
#   Optimization finished in  5m 4.65s
#   Simulated transport in  0.49s

# %%
po.plot_site(['smo','brw','spo','mlo'])

# %%
vf = Visualize_Fluxes('first_try')
vf.plot_region(['North American Boreal', 'North American Temperate', 'South American Tropical', 'South American Temperate'])
